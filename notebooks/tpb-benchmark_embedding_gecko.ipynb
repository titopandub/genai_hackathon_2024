# %%
import pandas as pd
import numpy as np

from google.cloud import aiplatform
from vertexai.language_models import TextEmbeddingModel
from tqdm._tqdm_notebook import tqdm_notebook

aiplatform.init(
    project='vidio-quiz-prod',
    location='asia-southeast1',
    staging_bucket='gs://genai_hackathon_2024',
)
tqdm_notebook.pandas()

model = TextEmbeddingModel.from_pretrained("textembedding-gecko-multilingual")

def embedding_text(model, text):
    embeddings = model.get_embeddings([text])
    for embedding in embeddings:
        vector = embedding.values
        # print(f"Length of Embedding Vector: {len(vector)}")
    return vector

# %%
from datetime import datetime


def preprocess_film_metadata(df):
    df.fillna('', inplace=True)
    df['id'] = df['id'].astype(str)
    df['title'] = df['film_title'].str.lower()
    df['group_l1'] = df['group_name_l1'].str.lower()
    df['group_l2'] = df['group_name_l2'].str.lower()
    df['genres'] = df['film_genres'].apply(lambda x: ', '.join(x.split(',')))
    df['actors'] = df['film_actors'].apply(lambda x: ', '.join(x.split(',')))
    df['directors'] = df['film_directors'].apply(lambda x: ', '.join(x.split(',')))
    df.loc[df['actors'] == "various", 'actors'] = ""
    df['country'] = df['country_group'].str.lower()
    df['total_watchers'] = df['total_watchers'].astype('int')
    df['release_date'] = df['release_date'].str.replace(" 00:00:00", "")
    df['release_year'] = df['release_date'].apply(lambda x: str(datetime.strptime(str(x), "%Y-%m-%d").year) if x != '' else '')

    def popularity(total_watchers):
        if total_watchers >= 50000:
            return "trending"
        elif total_watchers < 50000 and total_watchers >= 500:
            return "average"
        else:
            return "below average"

    df['popularity'] = df['total_watchers'].apply(lambda x: popularity(x))
    search_text_columns = ['title', 'description', 'group_l1', 'group_l2', 'film_main_genre', 'genres', 'directors', 'actors', 'country', 'release_year', 'age_rating', 'popularity']
    df['search_text'] = df[search_text_columns].apply(lambda row: search_text(*row), axis=1)
    df = df.loc[:,~df.columns.duplicated()]
    df.drop(columns=['film_title', 'group_name_l1', 'group_name_l2', 'film_main_genre', 'film_genres', 'film_directors', 'film_actors', 'country_group'], inplace=True)
    return df


def search_text(title, description, group_l1, group_l2, main_genre, genres, directors, actors, country, release_year, age_rating, popularity):
    
    return f"""title: {title}
actors: {actors}
group: {group_l1} > {group_l2}
genres: {main_genre}, {genres}
directors: {directors}
description: {description}
country: {country}
release year: {release_year}
age rating: {age_rating}
popularity: {popularity}"""

# %%
df = pd.read_excel('data/search_ground_truth.xlsx')
df.tail()
# Out:
# /home/tito/.venv/genai_hackathon_2024/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                   query query_type  content_id  total_click  position  score
# 14362            zombie     search        7323          138         4      2
# 14363            zombie     search        6116          135         5      1
# 14364  zombie detective     search        1838          101         1      2
# 14365  zombie detective     search        2466           12         2      1
# 14366             zorro     search        7765           13         1      1

# %%
film_df = pd.read_excel('data/film_metadata.xlsx', converters={'release_date':str})
film_df = preprocess_film_metadata(film_df)
film_df['embedding'] = film_df.progress_apply(lambda x: embedding_text(model, x['search_text']), axis=1)
film_df.head()
# Out:
# /home/tito/.venv/genai_hackathon_2024/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   0%|          | 0/5757 [00:00<?, ?it/s]
#      id                                        description release_date  \
# 0  9643  Aliza terpaksa menerima perjodohan dari Bunda ...   2024-03-09
# 1  7617  Menceritakan kisah seorang gadis bernama Sakin...   2023-03-13
# 2  7576  Naura (Basmalah), Rahsya (Raden Rakha), Adara ...   2023-02-23
# 3  8928  Di hari perayaan anniversary pernikahan Shafir...   2023-10-04
# 4  9372  Lasja mendapati suami dan ayahnya terlibat dal...   2024-02-29
#
#    total_watchers  age_rating                   image_portrait  \
# 0         1083307  18 or more  santri-pilihan-bunda-ee25e0.jpg
# 1          239263  13 or more      bidadari-surgamu-2bbb68.jpg
# 2          238254  13 or more               magic-5-def33f.jpg
# 3          223074  13 or more   di-antara-dua-cinta-bddc55.jpg
# 4          207446  18 or more             ratu-adil-eede53.jpg
#
#                           content_url  \
# 0  https://www.vidio.com/premier/9643
# 1  https://www.vidio.com/premier/7617
# 2  https://www.vidio.com/premier/7576
# 3  https://www.vidio.com/premier/8928
# 4  https://www.vidio.com/premier/9372
#
#                                            image_url  is_premium  \
# 0  https://thumbor.prod.vidiocdn.com/-PVWRIp3f0rh...        True
# 1  https://thumbor.prod.vidiocdn.com/JxL1jUZmTFdc...        True
# 2  https://thumbor.prod.vidiocdn.com/kha0tcadN-wD...        True
# 3  https://thumbor.prod.vidiocdn.com/rnBg59O6bVIy...        True
# 4  https://thumbor.prod.vidiocdn.com/L5oJmXWkmnEo...        True
#
#                   title group_l1        group_l2  \
# 0  santri pilihan bunda   series  vidio original
# 1      bidadari surgamu   series     tv sinetron
# 2               magic 5   series     tv sinetron
# 3   di antara dua cinta   series     tv sinetron
# 4             ratu adil   series  vidio original
#
#                            genres  \
# 0      adaptation, drama, romance
# 1  drama, family, religi, romance
# 2      drama, fantasy, friendship
# 3                  drama, romance
# 4            action, crime, drama
#
#                                               actors  \
# 0  fadi alaydrus, naura ayu, sarah sechan, teuku ...
# 1  josephine firmstone, michelle joan, rizky naza...
# 2  afan da5, basmalah, eby da 5, raden rakha, sri...
# 3  anggika bolsterli, anthony xie, asha assuncao,...
# 4  abdurrahman arif, andri mashadi, budi ros, dia...
#
#                                            directors    country release_year  \
# 0                                    angling sagaran  indonesia         2024
# 1                                    anurag vaishnav  indonesia         2023
# 2  a. septian, bobby moeryawan, sondang pratama, ...  indonesia         2023
# 3                                        deni pusung  indonesia         2023
# 4                           ginanti rona, tommy dewo  indonesia         2024
#
#   popularity                                        search_text  \
# 0   trending  title: santri pilihan bunda\nactors: fadi alay...
# 1   trending  title: bidadari surgamu\nactors: josephine fir...
# 2   trending  title: magic 5\nactors: afan da5, basmalah, eb...
# 3   trending  title: di antara dua cinta\nactors: anggika bo...
# 4   trending  title: ratu adil\nactors: abdurrahman arif, an...
#
#                                            embedding
# 0  [0.0015386489685624838, -0.02811456471681595, ...
# 1  [0.013242288492619991, -0.0075963991694152355,...
# 2  [0.04730440303683281, 0.02769733965396881, 0.0...
# 3  [0.0017294461140409112, -0.0005878254305571318...
# 4  [-0.007469169329851866, -0.009112628176808357,...

# %%
joined_df = df.merge(film_df[['id', 'search_text', 'embedding']], left_on='query', right_on='id', how='left')
joined_df.drop(columns=['id'], inplace=True)
joined_df['search_text'] = np.where(joined_df['query_type'] == 'search', joined_df['query'], joined_df['search_text'])

# %%
joined_df[joined_df['query_type'] != 'film_id'].size
# Out:
# 37472

# %%
trial_df = joined_df[joined_df['query_type'] != 'film_id'].head()

# %%
trial_df['embedding'] = trial_df.progress_apply(lambda x: embedding_text(model, x['search_text']), axis=1)
trial_df
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#              query query_type  content_id  total_click  position  score  \
# 146      12 strong     search        4724           22         1      1
# 666        172 day     search        7337           26         1      1
# 667       172 days     search        7337          131         1      2
# 668       172 days     search        2525           12         2      1
# 669  172 days film     search        7337           13         1      1
#
#        search_text                                          embedding
# 146      12 strong  [0.00753067247569561, -0.01148197054862976, 0....
# 666        172 day  [-0.01306532695889473, -0.0531916543841362, 0....
# 667       172 days  [-0.0369473472237587, -0.040300723165273666, 0...
# 668       172 days  [-0.0369473472237587, -0.040300723165273666, 0...
# 669  172 days film  [-0.032957036048173904, -0.03768826276063919, ...

# %%
joined_df[joined_df['query_type'] != 'film_id'].head()
# Out:
#              query query_type  content_id  total_click  position  score  \
# 146      12 strong     search        4724           22         1      1
# 666        172 day     search        7337           26         1      1
# 667       172 days     search        7337          131         1      2
# 668       172 days     search        2525           12         2      1
# 669  172 days film     search        7337           13         1      1
#
#        search_text embedding
# 146      12 strong       NaN
# 666        172 day       NaN
# 667       172 days       NaN
# 668       172 days       NaN
# 669  172 days film       NaN

# %%
# slow operation
joined_df['embedding'] = joined_df.progress_apply(lambda x: embedding_text(model, x['search_text']) if x['query_type'] == 'search' else x['embedding'], axis=1)
# Out:
#   0%|          | 0/14367 [00:00<?, ?it/s]

# %%
joined_df = joined_df.dropna(subset=['search_text', 'embedding'])

# %%
joined_df[joined_df['query_type'] != 'film_id'].head()
# Out:
#              query query_type  content_id  total_click  position  score  \
# 146      12 strong     search        4724           22         1      1
# 666        172 day     search        7337           26         1      1
# 667       172 days     search        7337          131         1      2
# 668       172 days     search        2525           12         2      1
# 669  172 days film     search        7337           13         1      1
#
#        search_text                                          embedding
# 146      12 strong  [0.00753067247569561, -0.01148197054862976, 0....
# 666        172 day  [-0.01306532695889473, -0.0531916543841362, 0....
# 667       172 days  [-0.0369473472237587, -0.040300723165273666, 0...
# 668       172 days  [-0.0369473472237587, -0.040300723165273666, 0...
# 669  172 days film  [-0.032957036048173904, -0.03768826276063919, ...

# %%
joined_df[joined_df['query_type'] == 'film_id'].head()
# Out:
#   query query_type  content_id  total_click  position  score  \
# 0  1003    film_id        1027          143         1      5
# 1  1003    film_id         831           90         2      4
# 2  1003    film_id        1559           81         3      3
# 3  1003    film_id        2415           52         4      2
# 4  1003    film_id        1299           46         5      1
#
#                                          search_text  \
# 0  title: hot young bloods\nactors: kim hee-won, ...
# 1  title: hot young bloods\nactors: kim hee-won, ...
# 2  title: hot young bloods\nactors: kim hee-won, ...
# 3  title: hot young bloods\nactors: kim hee-won, ...
# 4  title: hot young bloods\nactors: kim hee-won, ...
#
#                                            embedding
# 0  [0.008422765880823135, 0.013056890107691288, 0...
# 1  [0.008422765880823135, 0.013056890107691288, 0...
# 2  [0.008422765880823135, 0.013056890107691288, 0...
# 3  [0.008422765880823135, 0.013056890107691288, 0...
# 4  [0.008422765880823135, 0.013056890107691288, 0...

# %%
from annoy import AnnoyIndex
annoy_index = AnnoyIndex(768, 'dot')
for index, row in film_df.iterrows():
    annoy_index.add_item(int(row['id']), row['embedding'])
annoy_index.build(30)

def retrieve_by_embedding(embedding):
    if len(embedding) > 0:
        return annoy_index.get_nns_by_vector(embedding, 20, search_k=-1)
    else:
        return []

# %%
trial_df['search_result'] = trial_df.progress_apply(lambda x: retrieve_by_embedding(x['embedding']), axis=1)
trial_df
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#              query query_type  content_id  total_click  position  score  \
# 146      12 strong     search        4724           22         1      1
# 666        172 day     search        7337           26         1      1
# 667       172 days     search        7337          131         1      2
# 668       172 days     search        2525           12         2      1
# 669  172 days film     search        7337           13         1      1
#
#        search_text                                          embedding  \
# 146      12 strong  [0.00753067247569561, -0.01148197054862976, 0....
# 666        172 day  [-0.01306532695889473, -0.0531916543841362, 0....
# 667       172 days  [-0.0369473472237587, -0.040300723165273666, 0...
# 668       172 days  [-0.0369473472237587, -0.040300723165273666, 0...
# 669  172 days film  [-0.032957036048173904, -0.03768826276063919, ...
#
#                                          search_result
# 146  [4724, 7069, 9158, 9019, 9263, 7641, 7799, 384...
# 666  [9671, 4736, 9150, 9687, 9204, 5928, 1855, 725...
# 667  [9671, 4736, 7881, 5928, 9687, 9204, 9150, 241...
# 668  [9671, 4736, 7881, 5928, 9687, 9204, 9150, 241...
# 669  [9671, 4147, 5107, 9348, 9150, 9151, 5102, 798...

# %%
joined_df['search_result'] = joined_df.progress_apply(lambda x: retrieve_by_embedding(x['embedding']), axis=1)
# Out:
#   0%|          | 0/14262 [00:00<?, ?it/s]

# %%
joined_df.head()
# Out:
#   query query_type  content_id  total_click  position  score  \
# 0  1003    film_id        1027          143         1      5
# 1  1003    film_id         831           90         2      4
# 2  1003    film_id        1559           81         3      3
# 3  1003    film_id        2415           52         4      2
# 4  1003    film_id        1299           46         5      1
#
#                                          search_text  \
# 0  title: hot young bloods\nactors: kim hee-won, ...
# 1  title: hot young bloods\nactors: kim hee-won, ...
# 2  title: hot young bloods\nactors: kim hee-won, ...
# 3  title: hot young bloods\nactors: kim hee-won, ...
# 4  title: hot young bloods\nactors: kim hee-won, ...
#
#                                            embedding  \
# 0  [0.008422765880823135, 0.013056890107691288, 0...
# 1  [0.008422765880823135, 0.013056890107691288, 0...
# 2  [0.008422765880823135, 0.013056890107691288, 0...
# 3  [0.008422765880823135, 0.013056890107691288, 0...
# 4  [0.008422765880823135, 0.013056890107691288, 0...
#
#                                        search_result
# 0  [1003, 1517, 7334, 1314, 1027, 1554, 1193, 131...
# 1  [1003, 1517, 7334, 1314, 1027, 1554, 1193, 131...
# 2  [1003, 1517, 7334, 1314, 1027, 1554, 1193, 131...
# 3  [1003, 1517, 7334, 1314, 1027, 1554, 1193, 131...
# 4  [1003, 1517, 7334, 1314, 1027, 1554, 1193, 131...

# %%
def is_true_positive(row):
    return 1 if row['content_id'] in row['search_result'] else 0

# %%
joined_df['is_tp'] = joined_df.progress_apply(is_true_positive, axis=1)
# Out:
#   0%|          | 0/14262 [00:00<?, ?it/s]

# %%
joined_df[['is_tp']].describe()
# Out:
#               is_tp
# count  14262.000000
# mean       0.248002
# std        0.431868
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
joined_df[joined_df['query_type'] == 'search'][['is_tp']].describe()
# Out:
#              is_tp
# count  4684.000000
# mean      0.342656
# std       0.474648
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
joined_df[joined_df['query_type'] != 'search'][['is_tp']].describe()
# Out:
#              is_tp
# count  9578.000000
# mean      0.201712
# std       0.401299
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
joined_df[joined_df['query'] == 'ratu adil']
# Out:
#            query query_type  content_id  total_click  position  score  \
# 13181  ratu adil     search        9372         3184         1      7
# 13182  ratu adil     search        5421          221         2      6
# 13183  ratu adil     search        1756          208         3      5
# 13184  ratu adil     search        3111           75         4      4
# 13185  ratu adil     search        3982           21         5      1
# 13186  ratu adil     search        8957           21         5      1
# 13187  ratu adil     search        5178           21         5      1
#
#       search_text                                          embedding  \
# 13181   ratu adil  [-0.009534591808915138, -0.01045189332216978, ...
# 13182   ratu adil  [-0.009534591808915138, -0.01045189332216978, ...
# 13183   ratu adil  [-0.009534591808915138, -0.01045189332216978, ...
# 13184   ratu adil  [-0.009534591808915138, -0.01045189332216978, ...
# 13185   ratu adil  [-0.009534591808915138, -0.01045189332216978, ...
# 13186   ratu adil  [-0.009534591808915138, -0.01045189332216978, ...
# 13187   ratu adil  [-0.009534591808915138, -0.01045189332216978, ...
#
#                                            search_result  is_tp
# 13181  [6147, 731, 6100, 497, 499, 9538, 5699, 5735, ...      0
# 13182  [6147, 731, 6100, 497, 499, 9538, 5699, 5735, ...      0
# 13183  [6147, 731, 6100, 497, 499, 9538, 5699, 5735, ...      0
# 13184  [6147, 731, 6100, 497, 499, 9538, 5699, 5735, ...      0
# 13185  [6147, 731, 6100, 497, 499, 9538, 5699, 5735, ...      0
# 13186  [6147, 731, 6100, 497, 499, 9538, 5699, 5735, ...      0
# 13187  [6147, 731, 6100, 497, 499, 9538, 5699, 5735, ...      0

# %%
film_df[film_df['id'] == '5421']
# Out:
#       id                                        description release_date  \
# 25  5421  Walau berusaha keluar dari lingkaran setan, El...   2023-11-03
#
#     total_watchers  age_rating                    image_portrait  \
# 25           33155  18 or more  pertaruhan-the-series-5e7b33.jpg
#
#                            content_url  \
# 25  https://www.vidio.com/premier/5421
#
#                                             image_url  is_premium  \
# 25  https://thumbor.prod.vidiocdn.com/jz6vOt9OQORS...        True
#
#                     title group_l1        group_l2  \
# 25  pertaruhan the series   series  vidio original
#
#                                         genres  \
# 25  action, adaptation, crime, drama, thriller
#
#                                                actors  \
# 25  aulia sarah, bio one, clara bernadeth, giulio ...
#
#                               directors    country release_year popularity  \
# 25  fajar martha santosa, sidharta tata  indonesia         2023    average
#
#                                           search_text  \
# 25  title: pertaruhan the series\nactors: aulia sa...
#
#                                             embedding
# 25  [0.013054502196609974, -0.010694384574890137, ...

# %%
joined_df.drop(columns=['search_result', 'is_tp']).to_json('data/benchmark_gecko.json', orient='records', lines=True)
