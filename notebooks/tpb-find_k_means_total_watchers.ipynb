# %%
#ganti ke pandas xlsx
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from kneed import KneeLocator
import matplotlib.pyplot as plt

df = pd.read_excel('film_metadata.xlsx', converters={'release_date':str})
df.head()
# Out:
# /home/tito/.venv/genai_hackathon_2024/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      id          film_title group_name_l1   group_name_l2 film_main_genre  \
# 0  9372           Ratu Adil        Series  Vidio Original           crime
# 1  9456  Cinta Pertama Ayah        Series  Vidio Original           crime
# 2  7617    Bidadari Surgamu        Series     TV Sinetron           drama
# 3  7576             Magic 5        Series     TV Sinetron           drama
# 4  9535       Tertawan Hati        Series     TV Sinetron           drama
#
#                    film_genres  \
# 0           action,crime,drama
# 1   crime,drama,family,mystery
# 2  drama,family,religi,romance
# 3     drama,fantasy,friendship
# 4                drama,romance
#
#                                       film_directors  \
# ...

# %%
# scaler = StandardScaler()
# df['total_watchers_scaled'] = scaler.fit_transform(df[['total_watchers']])

# %%
# inertia = []
# K_range = range(1, 10)

# for k in K_range:
#     kmeans = KMeans(n_clusters=k, random_state=42).fit(df[['total_watchers_scaled']])
#     inertia.append(kmeans.inertia_)

# %%
# plt.figure(figsize=(8, 4))
# plt.plot(K_range, inertia, marker='o')
# plt.xlabel('Number of clusters')
# plt.ylabel('Inertia')
# plt.title('Elbow Method For Optimal k')
# plt.show()

# %%
# Use KneeLocator to find the elbow point
# kn = KneeLocator(K_range, inertia, curve='convex', direction='decreasing')
# print(f"Optimal number of categories (clusters): {kn.knee}")

# %%
# Perform KMeans clustering again with the optimal number of clusters
# optimal_k = 5
# kmeans_final = KMeans(n_clusters=optimal_k, random_state=42).fit(df[['total_watchers_scaled']])
# df['category'] = kmeans_final.labels_

# %%
# To find the thresholds, look at the cluster centers and scale them back
# thresholds = scaler.inverse_transform(kmeans_final.cluster_centers_)
# print(f"Thresholds for each category: {thresholds.flatten()}")
# Out:
# Thresholds for each category: [   408.03759791 303261.66666667 213068.          49879.95
#  393890.        ]

# %%
df.fillna('', inplace=True)

# %%
def popularity(total_watchers):
    if total_watchers >= 50000:
        return "trending"
    elif total_watchers < 50000 and total_watchers >= 500:
        return "average"
    else:
        return "below average"

df['popularity'] = df['total_watchers'].apply(lambda x: popularity(x))

# %%
df['release_date'] = df['release_date'].str.replace(" 00:00:00", "")

# %%
from datetime import datetime
import numpy as np

df['release_year'] = df['release_date'].apply(lambda x: datetime.strptime(str(x), "%Y-%m-%d").year if x != '' else '')

# %%
df.head()
# Out:
#      id          film_title group_name_l1   group_name_l2 film_main_genre  \
# 0  9372           Ratu Adil        Series  Vidio Original           crime
# 1  9456  Cinta Pertama Ayah        Series  Vidio Original           crime
# 2  7617    Bidadari Surgamu        Series     TV Sinetron           drama
# 3  7576             Magic 5        Series     TV Sinetron           drama
# 4  9535       Tertawan Hati        Series     TV Sinetron           drama
#
#                    film_genres  \
# 0           action,crime,drama
# 1   crime,drama,family,mystery
# 2  drama,family,religi,romance
# 3     drama,fantasy,friendship
# 4                drama,romance
#
#                                       film_directors  \
# 0                            ginanti rona,tommy dewo
# 1                                  hadrah daeng ratu
# 2                                    anurag vaishnav
# 3  a. septian,bobby moeryawan,sondang pratama,usm...
# 4                                 sanjeev ram kishan
#
# ...
