# %%
import pandas as pd
from tqdm._tqdm_notebook import tqdm_notebook


tqdm_notebook.pandas()
# Out:
# /tmp/ipykernel_95711/1047569264.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
df = pd.read_excel('data/chat_routing_fix.xlsx')
df.head()
# Out:
#                                              query           route  \
# 0           dian sastro membintangi film apa saja?      vidio-info
# 1                                             halo      vidio-info
# 2                                    kenapa kurma?      vidio-info
# 3  Carikan saya 1 series terbaik yang ada di vidio  recommendation
# 4                                   reza rahardian      vidio-info
#
#             human
# 0  recommendation
# 1      vidio-info
# 2      vidio-info
# 3  recommendation
# 4      vidio-info

# %%
from langchain_google_vertexai import VertexAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate


model = VertexAI(model_name="gemini-pro", project="vidio-quiz-prod", location="asia-southeast1", temperature=0.4)
route_chain = (
    PromptTemplate.from_template(
        """You are chatbot for Vidio OTT platform        
Given the user question below, classify it as either being about
`recommendation` if question related to user want film recommendation
`schedule` if question related to sport match schedule or sport team
`vidio-info` otherwise

Do not respond with other word than specified.

<user_query>
{user_query}
</user_query>

Classification:
"""
    ) | model | StrOutputParser() 
)

def chain_route(user_query):
    try:
        return route_chain.invoke({"user_query": user_query})
    except IndexError as e:
        return ""

# %%
df['llm'] = df['query'].progress_apply(lambda x: chain_route(x))
# Out:
#   0%|          | 0/224 [00:00<?, ?it/s]

# %%
df['recall'] = df.apply(lambda x: 1 if x['human'] == x['llm'] else 0, axis=1)

# %%
df['recall'].describe()
# Out:
# count    224.000000
# mean       0.821429
# std        0.383851
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: recall, dtype: float64

# %%
df[(df['human'] == 'vidio-info')]['recall'].describe()
# Out:
# count    127.000000
# mean       0.685039
# std        0.466340
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: recall, dtype: float64

# %%
df[(df['human'] == 'vidio-info') & (df['recall'] == 0)]
# Out:
#                                                  query       route  \
# 4                                       reza rahardian  vidio-info
# 8          Apa sinopsis dari serial Happiness di atas?  vidio-info
# 12        apa yang bagus dari film ratu adil di vidio?  vidio-info
# 20     tapi film-film ini tidak sama dengan sebelumnya  vidio-info
# 27                     film yang dimainkan idan sastro  vidio-info
# 40                                    itu sudah tamat?  vidio-info
# 41                              berikan link ratu adil  vidio-info
# 44   virio original series apa yang sedang berjalan...  vidio-info
# 57                        di vidio ada film bokep gak?  vidio-info
# 60                    rekomendasikan konten porno dong  vidio-info
# 67                                               3* 38       other
# 69                          siapa pemeran FTV populer?  vidio-info
# 71                     ada konten yang semi porno gak?  vidio-info
# 96                         rekomendasikan konten bokep  vidio-info
# 104                    film yang dimainkan dian sastro  vidio-info
# 106      berikan saya daftar konten terbaru dari vidio  vidio-info
# 107                               ada film terbaru apa  vidio-info
# 109                    siapa yang membunuh ayah lasja?  vidio-info
# 112                                    jangan india om  vidio-info
# 119                       ratu adil ada berapa episode  vidio-info
# 120                                          ratu adil  vidio-info
# 122                                         mau nonton       other
# 127                                   mau nonton bokep  vidio-info
# 135                               film baru di netflix  vidio-info
# 136                      apakah kamu punya film porno?  vidio-info
# 141                  di vidio ada film godzilla ga ya?  vidio-info
# 142             ratu adil totalnya ada berapa episode?  vidio-info
# 159                                kalau konten bokep?  vidio-info
# 174          saya ingin menonton highlight nba terbaik  vidio-info
# 176  bisa tolong berikan saya list konten terbaru d...  vidio-info
# 177                    apakah ada film Dilan di Vidio?  vidio-info
# 180                           Episode Ghara vs Deidara  vidio-info
# 182  episode berapa saat ayah Lasja tewas ditembak ...  vidio-info
# 186                apa yang bagus dari film ratu adil?  vidio-info
# 188                     genre apa yang sedang trending  vidio-info
# 189                   games yang paling seru di vidio?  vidio-info
# 193                        saya sudah nonton itu semua  vidio-info
# 202                   Apa film pertama yang kamu tahu?  vidio-info
# 206                                               anya  vidio-info
# 208  apakah paket diamond sudah termasuk konten pre...  vidio-info
#
#           human             llm  recall      similarity
# 4    vidio-info  recommendation       0  recommendation
# 8    vidio-info  recommendation       0  recommendation
# 12   vidio-info  recommendation       0  recommendation
# 20   vidio-info  recommendation       0  recommendation
# 27   vidio-info  recommendation       0  recommendation
# 40   vidio-info  recommendation       0  recommendation
# 41   vidio-info  recommendation       0  recommendation
# 44   vidio-info  recommendation       0      vidio-info
# 57   vidio-info                       0      vidio-info
# 60   vidio-info                       0  recommendation
# 67   vidio-info        schedule       0        schedule
# 69   vidio-info  recommendation       0  recommendation
# 71   vidio-info                       0  recommendation
# 96   vidio-info                       0  recommendation
# 104  vidio-info  recommendation       0  recommendation
# 106  vidio-info  recommendation       0      vidio-info
# 107  vidio-info  recommendation       0  recommendation
# 109  vidio-info  recommendation       0  recommendation
# 112  vidio-info  recommendation       0  recommendation
# 119  vidio-info  recommendation       0  recommendation
# 120  vidio-info  recommendation       0  recommendation
# 122  vidio-info  recommendation       0  recommendation
# 127  vidio-info                       0      vidio-info
# 135  vidio-info  recommendation       0  recommendation
# 136  vidio-info                       0  recommendation
# 141  vidio-info  recommendation       0      vidio-info
# 142  vidio-info  recommendation       0  recommendation
# 159  vidio-info                       0  recommendation
# 174  vidio-info        schedule       0  recommendation
# 176  vidio-info  recommendation       0      vidio-info
# 177  vidio-info  recommendation       0      vidio-info
# 180  vidio-info  recommendation       0      vidio-info
# 182  vidio-info  recommendation       0  recommendation
# 186  vidio-info  recommendation       0  recommendation
# 188  vidio-info  recommendation       0  recommendation
# 189  vidio-info        schedule       0      vidio-info
# 193  vidio-info  recommendation       0  recommendation
# 202  vidio-info  recommendation       0  recommendation
# 206  vidio-info  recommendation       0  recommendation
# 208  vidio-info        schedule       0  recommendation

# %%
from vertexai.language_models import TextEmbeddingModel
model = TextEmbeddingModel.from_pretrained("textembedding-gecko-multilingual")

def embedding_text(model, text):
    embeddings = model.get_embeddings([text])
    for embedding in embeddings:
        vector = embedding.values
        # print(f"Length of Embedding Vector: {len(vector)}")
    return vector

# %%
import numpy as np

template_recommendation = """You are content expert from OTT company.
Your task is to give recommendation based on User Query, Movie Data retrieved from Vector Search and User History.
The answer in **Bahasa Indonesia**, give **5 (five)** recommendation, re-rank the recommendation based on User Query and User History relevancy.
{format_instructions}
Always use title case for title field.
Do not recommend content from User History unless it really relevant for them based on their query.
Give the explanation for each content why it relevant for the user based on the User Query, User Profile, Vector Search Result and User History. The explanation should show only if it is relevant to be shown to user and summarize it based on User Query and User History.

Here is the context.
{user_profile}

User Query: {user_query}

Vector Search Result:
{vector_search_result}

User History:
{user_history}"""

template_schedule = """"Based on context answer following question, answer with human readable form.
Context:
{context}
Question: {user_question}
Answer:"""

template_vidio_info = """You are chatbot for Vidio OTT platform. Your task is to answer to user question
Question can is related to vidio. Like about vidio product, and film.
Or question can be unrelated to vidio

Here are the useful information:
<information>
{information} 
</information>

User Question:
<user_query>
{user_query}
</user_query>"""

prompt_templates = [template_recommendation, template_schedule, template_vidio_info]
prompt_embeddings = [embedding_text(model, text) for text in prompt_templates]

def prompt_router(input):
    query_embedding = embedding_text(model, input)
    # similarity = cosine_similarity([query_embedding], prompt_embeddings)[0]
    similarity = [np.dot(query_embedding, prompt_embedding) for prompt_embedding in prompt_embeddings]
    most_similar_index = np.argmax(similarity)
    answers = ['recommendation', 'schedule', 'vidio-info']
    return answers[most_similar_index]

# %%
similarity_df = df.copy()
similarity_df['similarity'] = similarity_df.progress_apply(lambda x: prompt_router(x['query']), axis=1)
similarity_df['recall'] = similarity_df.apply(lambda x: 1 if x['human'] == x['similarity'] else 0, axis=1)
# Out:
#   0%|          | 0/224 [00:00<?, ?it/s]

# %%
similarity_df['recall'].describe()
# Out:
# count    224.000000
# mean       0.549107
# std        0.498697
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: recall, dtype: float64

# %%
similarity_df[(similarity_df['human'] == 'vidio-info')]['recall'].describe()
# Out:
# count    127.000000
# mean       0.322835
# std        0.469412
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: recall, dtype: float64

# %%
similarity_df[(similarity_df['human'] == 'vidio-info') & (similarity_df['recall'] == 0)]
# Out:
#                                            query       route       human  \
# 1                                           halo  vidio-info  vidio-info
# 2                                  kenapa kurma?  vidio-info  vidio-info
# 4                                 reza rahardian  vidio-info  vidio-info
# 8    Apa sinopsis dari serial Happiness di atas?  vidio-info  vidio-info
# 10                       how long to beat sekiro       other  vidio-info
# ..                                           ...         ...         ...
# 214                     siapa presiden indonesia  vidio-info  vidio-info
# 217                                        apple  vidio-info  vidio-info
# 220                       generenya apa saja itu  vidio-info  vidio-info
# 221                                selamat siang  vidio-info  vidio-info
# 222                                siapa prabowo  vidio-info  vidio-info
#
#                 llm  recall      similarity
# 1        vidio-info       0  recommendation
# 2        vidio-info       0  recommendation
# 4    recommendation       0  recommendation
# 8    recommendation       0  recommendation
# 10       vidio-info       0  recommendation
# ..              ...     ...             ...
# 214      vidio-info       0  recommendation
# 217      vidio-info       0        schedule
# 220      vidio-info       0  recommendation
# 221      vidio-info       0  recommendation
# 222      vidio-info       0  recommendation
#
# [86 rows x 6 columns]
