# %%
import vertexai
from vertexai.language_models import TextEmbeddingModel
from annoy import AnnoyIndex
import pandas as pd

import requests
import os
from dotenv import load_dotenv
import json
from IPython.display import display, Markdown

from langchain_google_vertexai import VertexAI
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableBranch

from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()
load_dotenv()

vertexai.init(project="vidio-quiz-prod", location="asia-southeast1")
embedding_model = TextEmbeddingModel.from_pretrained("textembedding-gecko-multilingual")
model = VertexAI(model_name="gemini-pro")
# Out:
# /tmp/ipykernel_384247/572403084.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
history_df = pd.read_excel('data/route.xlsx')
test_df = history_df.copy()

history_df['actual_route'] = history_df.apply(lambda x: x["history_route"], axis=1)
history_df['is_tp'] = history_df.apply(lambda x: 1 if x["actual_route"] == x["expected_route"] else 0, axis=1)
history_df = history_df.drop('history_route', axis=1)

test_df = test_df.drop('history_route', axis=1)

# %%
prompt_1 = """You are chatbot for Vidio OTT platform
Given the user question below, classify it as either being about
`recommendation` if question related to user want film recommendation
`vidio` if question related to vidio
`other` otherwise

Do not respond with more than one word.

<user_query>
{user_query}
</user_query>

Classification:
"""

prompt_2 = """You are chatbot for Vidio OTT platform
Given the user question below, classify it as either being about
`recommendation` if question related to user want film recommendation, not games or acade
`customer service` if question related to user problem and trouble
`vidio` if question related about vidio product, feature, faq, film, games, or arcade
`other` otherwise

Do not respond with more than one word.

Input:
<user_query>
{user_query}
</user_query>
Classification:
"""

prompt_3 = """You are chatbot for Vidio OTT platform
Given the user question below, classify it as either being about
`recommendation` if question related to user want film recommendation, not games or acade
`customer service` if question related to user problem and trouble
`vidio` if question related about vidio product, feature, faq, film, games, or arcade
`other` otherwise

Do not respond with more than one word.


Input: bagaimana topup energy
Classification: vidio

Input: berapa harga paket diamond
Classification: vidio

Input: kenapa aliza dijodohkan
Classification: vidio

Input: Tidak bisa menonton epl padahal sudah bayar
Classification: customer service

Input: pembayaran gagal
Classification: customer service

Input: Lagi patah hati nih
Classification: recommendation

Input: film yang dibintangi wulan guritno
Classification: recommendation

Input: film terbaru di vidio
Classification: recommendation

Input: saya mau nonton santri pilihan bunda
Classification: recommendation

Input: 1 + 1
Classification: other

Input: apa ibukota indonesia
Classification: other

Input:
<user_query>
{user_query}
</user_query>
Classification:
"""

# %%
user_query = "bagaimana mendaftar paket mahasiswa"

route_chain = (
    PromptTemplate.from_template(
        prompt_3
    ) | model | StrOutputParser() 
) 

resp = route_chain.invoke({"user_query": user_query}) 

def get_route(query):
    return route_chain.invoke({"user_query": query}) 

resp
# Out:
# 'vidio'

# %%
test_df['actual_route'] = test_df.progress_apply(lambda x: get_route(x["query"]), axis=1)
test_df['is_tp'] = test_df.apply(lambda x: 1 if x["actual_route"] == x["expected_route"] else 0, axis=1)
test_df
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]
#                                                 query    expected_route  \
# 0                        berapa harga paket mahasiswa             vidio
# 1                        berapa harga paket mahasiswa             vidio
# 2                              bagaimana topup energy             vidio
# 3                                tontonan patah patah  customer service
# 4                     bayar vidio bisa pakai apa saja             vidio
# ..                                                ...               ...
# 68  saya ingin menonton film romance tapi ada acti...    recommendation
# 69                      apa anime terpopuler sekarang    recommendation
# 70                                  lagi mood sedih\n    recommendation
# 71                              mau nonton film sedih    recommendation
# 72                             ada promo apa hari ini             vidio
#
#       actual_route  is_tp
# 0            vidio      1
# 1            vidio      1
# 2            vidio      1
# 3            vidio      0
# 4            vidio      1
# ..             ...    ...
# 68  recommendation      1
# 69  recommendation      1
# 70  recommendation      1
# 71  recommendation      1
# 72           vidio      1
#
# [73 rows x 4 columns]

# %%
# prompt_3
test_df[test_df['is_tp'] == 0]
# Out:
#                                                 query    expected_route  \
# 3                                tontonan patah patah  customer service
# 23                                siapa Aditya Haikal             other
# 30  episode berapa saat ayah Lasja tewas ditembak ...             vidio
# 32  film cinta pertama ayah bisa di tonton segala ...             vidio
# 34         tears of the sun menceritakan tentang apa?             vidio
# 35                   Is John Wick available in Vidio?    recommendation
# 56                            apa yang baru di vidio?    recommendation
# 57                             apa tontonan di Vidio?    recommendation
#
#       actual_route  is_tp
# 3            vidio      0
# 23           vidio      0
# 30  recommendation      0
# 32  recommendation      0
# 34  recommendation      0
# 35           vidio      0
# 56           vidio      0
# 57           vidio      0

# %%
# prompt_3
test_df[['is_tp']].describe()
# Out:
#            is_tp
# count  73.000000
# mean    0.890411
# std     0.314539
# min     0.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     1.000000

# %%
# prompt_2
test_df[test_df['is_tp'] == 0]
# Out:
#                                                 query  expected_route  \
# 2                              bagaimana topup energy           vidio
# 5                         berapa harga pake mahasiswa           vidio
# 23                                siapa Aditya Haikal           other
# 32  film cinta pertama ayah bisa di tonton segala ...           vidio
# 35                   Is John Wick available in Vidio?  recommendation
# 37        Ada film dari Martin Scorsese gak di Vidio?  recommendation
# 40                          Saya mau nonton ratu adil  recommendation
# 41                   Saya mau nonton film dian sastro  recommendation
# 44                   film yang dibintangi dian sastro  recommendation
# 56                            apa yang baru di vidio?  recommendation
# 57                             apa tontonan di Vidio?  recommendation
# 58  I want to watch movie "How to Catch a Dragon"....  recommendation
# 64                    series korea yang ada di vidio?  recommendation
# 66                                 film anak di vidio  recommendation
#
#         actual_route  is_tp
# 2              other      0
# 5   customer service      0
# 23             vidio      0
# 32    recommendation      0
# 35             vidio      0
# 37             vidio      0
# 40             vidio      0
# 41             vidio      0
# 44             vidio      0
# 56             vidio      0
# 57             vidio      0
# 58  customer service      0
# 64             vidio      0
# 66             vidio      0

# %%
# prompt_2
test_df[['is_tp']].describe()
# Out:
#            is_tp
# count  73.000000
# mean    0.808219
# std     0.396426
# min     0.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     1.000000

# %%
sample_df = test_df[test_df['is_tp'] == 0].copy()
test_df[test_df['is_tp'] == 0]
# Out:
#                                                 query     history_route  \
# 2                              bagaimana topup energy  customer service
# 10                             apa itu vidio arcade\t             other
# 13  apa saja paket yang bisa di tonton di semua pe...    recommendation
# 19                                              1 + 1             other
# 31                   games yang paling seru di vidio?    recommendation
# 32         tears of the sun menceritakan tentang apa?    recommendation
# 33                   Is John Wick available in Vidio?             other
# 34                                Lagi patah hati nih             other
# 45                                   lagi mood sedih2    recommendation
# 56  I want to watch movie "How to Catch a Dragon"....    recommendation
# 58                 film dengan aktris nya dian sastro    recommendation
#
#       expected_route      actual_route  is_tp
# 2   customer service             other      0
# 10  customer service             other      0
# 13  customer service             other      0
# 19             other             Other      0
# 31             other    recommendation      0
# 32             other    recommendation      0
# 33    recommendation             other      0
# 34    recommendation             other      0
# 45    recommendation             other      0
# 56    recommendation  customer service      0
# 58    recommendation             other      0

# %%
user_query = "bagaimana mendaftar paket mahasiswa"

route_chain = (
    PromptTemplate.from_template(
        """
You are chatbot for Vidio OTT platform        
Given the user question below, classify it as either being about `customer service`, `recommendation`, or `other`.
Only classify to recommendation if user ask for reccomendation

Do not respond with more than one word.

<user_query>
{user_query}
</user_query>

Classification:
"""
    ) | model | StrOutputParser() 
) 

resp = route_chain.invoke({"user_query": user_query}) 

def get_route(query):
    return route_chain.invoke({"user_query": query}) 

sample_df['actual_route'] = sample_df.progress_apply(lambda x: get_route(x["query"]), axis=1)
sample_df['is_tp'] = sample_df.apply(lambda x: 1 if x["actual_route"] == x["expected_route"] else 0, axis=1)

sample_df
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#                                                 query     history_route  \
# 2                              bagaimana topup energy  customer service
# 10                             apa itu vidio arcade\t             other
# 13  apa saja paket yang bisa di tonton di semua pe...    recommendation
# 19                                              1 + 1             other
# 31                   games yang paling seru di vidio?    recommendation
# 32         tears of the sun menceritakan tentang apa?    recommendation
# 33                   Is John Wick available in Vidio?             other
# 34                                Lagi patah hati nih             other
# 45                                   lagi mood sedih2    recommendation
# 56  I want to watch movie "How to Catch a Dragon"....    recommendation
# 58                 film dengan aktris nya dian sastro    recommendation
#
#       expected_route      actual_route  is_tp
# 2   customer service  customer service      1
# 10  customer service             other      0
# 13  customer service    recommendation      0
# 19             other             other      1
# 31             other    recommendation      0
# 32             other             other      1
# 33    recommendation             other      0
# 34    recommendation             other      0
# 45    recommendation    recommendation      1
# 56    recommendation  customer service      0
# 58    recommendation    recommendation      1

# %%
test_df_2 = test_df.copy()
test_df_2['actual_route'] = test_df_2.progress_apply(lambda x: get_route(x["query"]), axis=1)
test_df_2['is_tp'] = test_df_2.apply(lambda x: 1 if x["actual_route"] == x["expected_route"] else 0, axis=1)
test_df_2[['is_tp']].describe()
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
#            is_tp
# count  70.000000
# mean    0.828571
# std     0.379604
# min     0.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     1.000000

# %%
test_df_2[test_df_2['is_tp'] == 0]
# Out:
#                                                 query     history_route  \
# 0                        berapa harga paket mahasiswa  customer service
# 2                              bagaimana topup energy  customer service
# 5                         berapa harga pake mahasiswa  customer service
# 10                             apa itu vidio arcade\t             other
# 11                           bagaimana topup energy\t             other
# 12           berapa device yang bisa nonton sekaligus             other
# 13  apa saja paket yang bisa di tonton di semua pe...    recommendation
# 18                                              3* 38             other
# 31                   games yang paling seru di vidio?    recommendation
# 33                   Is John Wick available in Vidio?             other
# 34                                Lagi patah hati nih             other
# 56  I want to watch movie "How to Catch a Dragon"....    recommendation
#
#       expected_route      actual_route  is_tp
# 0   customer service             other      0
# 2   customer service             other      0
# 5   customer service             other      0
# 10  customer service             other      0
# 11  customer service             other      0
# 12  customer service             other      0
# 13  customer service             other      0
# 18             other             Other      0
# 31             other    recommendation      0
# 33    recommendation             other      0
# 34    recommendation             Other      0
# 56    recommendation  customer service      0

# %%
user_query = "bagaimana mendaftar paket mahasiswa"

route_chain = (
    PromptTemplate.from_template(
        """
You are chatbot for Vidio OTT platform. Your task is to answer to user question
Question can is related to vidio. Like about vidio product, and film.
Or question can be unrelated to vidio

Here are the useful information:
<information>
{information} 
</information>

User Question:
<user_query>
{user_query}
</user_query>

Classification:
"""
    ) | model | StrOutputParser() 
) 

resp = route_chain.invoke({"user_query": user_query}) 

def get_route(query):
    return route_chain.invoke({"user_query": query}) 

resp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 user_query = "bagaimana mendaftar paket mahasiswa"
#       3 route_chain = (
# ----> 4     PromptTemplate.from_template(
#       5         """
#       6 You are chatbot for Vidio OTT platform. Your task is to answer to user question
#       7 Question can is related to vidio. Like about vidio product, and film.
#       8 Or question can be unrelated to vidio
#       9
#      10 Here are the useful information:
#      11 <information>
#      12 {information}
#      13 </information>
#      14
#      15 User Question:
#      16 <user_query>
#      17 {user_query}
#      18 </user_query>
#      19
#      20 Classification:
#      21 """
#      22     ) | model | StrOutputParser()
#      23 )
#      25 resp = route_chain.invoke({"user_query": user_query})
#      27 def get_route(query):
#
# NameError: name 'PromptTemplate' is not defined
