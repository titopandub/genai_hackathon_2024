# %%
from langchain_google_alloydb_pg import AlloyDBEngine

from __future__ import annotations
import asyncio
from threading import Thread
from typing import Optional, Union
from google.cloud.alloydb.connector import IPTypes
from sqlalchemy.ext.asyncio import create_async_engine
from langchain_core.output_parsers import StrOutputParser

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_google_vertexai import VertexAI
from datetime import datetime

import time
from langchain_google_alloydb_pg import AlloyDBChatMessageHistory
from IPython.display import Markdown

model = VertexAI(model_name="gemini-pro", project="vidio-quiz-prod", location="asia-southeast1", temperature=0.4)
CHAT_MESSAGE_TABLE_NAME = "chat_messages"

async def monkey__create(
    cls,
    project_id: str,
    region: str,
    cluster: str,
    instance: str,
    database: str,
    ip_type: Union[str, IPTypes],
    user: Optional[str] = None,
    password: Optional[str] = None,
    loop: Optional[asyncio.AbstractEventLoop] = None,
    thread: Optional[Thread] = None,
):
    engine = create_async_engine(
        "postgresql+asyncpg://postgres:postgres@localhost:5432/postgres"
    )
    return AlloyDBEngine(engine, loop, thread)

AlloyDBEngine._create = monkey__create

engine = AlloyDBEngine.from_instance(
    project_id="",
    region="",
    cluster="",
    instance="",
    database="",
)

engine.init_chat_history_table(table_name="chat_messages")

# %%
info = """
Untuk mendaftarkan kampus kamu agar mendapatkan paket Vidio Platinum Mahasiswa, kamu bisa mendaftarkan melalui Form Ini , Pendaftaran terbatas hanya untuk email kampus tertentu. Setelah pendaftaran, kamu bisa coba beli lagi dalam 2x24 jam hari kerja.



Bagaimana cara mendaftarkan kampus saya agar mendapatkan paket Vidio Platinum Mahasiswa ?


# Bagaimana cara mendaftarkan kampus saya agar mendapatkan paket Vidio Platinum Mahasiswa ?



Jika kampus kamu belum terdaftar, kamu bisa mendaftarkan melalui[Form Ini](http://vid.id/daftardomain) , Pendaftaran terbatas hanya untuk email kampus tertentu. Setelah pendaftaran, kamu bisa coba beli lagi dalam 2x24 jam hari kerja.








Bagaimana cara membeli paket ini ?


# Bagaimana cara membeli paket ini ?



Untuk membeli paket ini, ikuti langkah berikut : 

1. Masuk atau daftar dengan email kampus
2. Pastikan sedang tidak memiliki paket aktif Platinum di Vidio
3. Verifikasi email-mu
4. Beli paketnya via [Paywall](https://www.vidio.com/plans?fpc=80) atau halaman [Platinum Mahasiswa](https://www.vidio.com/pages/234/paket-mahasiswa?layout=false&utm_source=product&utm_medium=faq_page&utm_campaign=platinum_mahasiswa_2023)
5. Langsung nonton di Vidio!








Syarat & Ketentuan Vidio Platinum Mahasiswa


# Syarat & Ketentuan Vidio Platinum Mahasiswa



Syarat & Ketentuan Vidio Platinum Mahasiswa

(selanjutnya disebut “Ketentuan Vidio Platinum Mahasiswa”)

Vidio Platinum Mahasiswa adalah paket streaming service khusus mahasiswa dengan harga yang lebih terjangkau yang disediakan oleh Vidio untuk memudahkan mahasiswa dalam menonton konten-konten eksklusif Vidio mulai dari konten olahraga lokal, badminton, tenis, dan lainnya serta original series Vidio mulai dari drama hingga aksi, film-film dan serial pilihan terbaik dari Indonesia, Korea, Thailand, India serta hiburan menarik lainnya. Streaming service baru ini sangat cocok untuk mahasiswa yang suka menonton 24/7 dimanapun kapanpun! Vidio Platinum Mahasiswa dapat diakses melalui internet ke handphone, laptop ataupun perangkat lainnya.

| 7 | Apakah barang-barang di aplikasi Vidio bisa dibeli dengan metode pembayaran lain selain Tiket? | Hadiah di Vidio Arcade bersifat eksklusif sehingga kamu hanya bisa mendapatkannya dengan menukar Tiket yang kamu punya dan Vidio tidak menerima bentuk/metode pembayaran di luar itu |
| 8 | Apakah barang-barang yang ada di Redemption Page Vidio Arcade asli atau original? | Setiap item hadiah yang ada di redemption page adalah asli dan terjamin originalitasnya. |
| 9 | Apakah Tiket bisa kadaluarsa? | Ya. Tiket akan kadaluarsa satu tahun mulai dari tiket itu diterima. |
| 10 | Apakah bisa dilakukan penukaran hadiah? | Untuk hadiah yang sudah di redeem dan diterima oleh Pemain tidak dapat ditukarkan baik dengan hadiah lain atau dilakukan retur kecuali ada kondisi tertentu untuk dilakukan pengembalian barang. S&K Berlaku. |
| 11 | Bagaimana cara kami menyampaikan keluhan atas item hadiah yang diterima? | Untuk setiap keluhan dan layanan customer service dapat menghubungi info@vidio.com |
| 12 | Apakah ada tambahan untuk biaya pengiriman? | Setiap pengiriman hadiah dari redemption center Vidio Arcade adalah gratis ongkir.  |
| 13 | Apakah tiket yang didapatkan dari kuis bisa ditukarkan pada hadiah yang ada di Redemption Center? | Setiap Tiket yang diperoleh baik dari kuis ataupun permainan Vidio Arcade bisa ditukar dengan setiap item hadiah yang tersedia di Redemption Page Center. |














Mengapa saya tidak dapat memproses media?


# Mengapa saya tidak dapat memproses media?



Setiap perangkat memiliki sebuah media codec yang berfungsi sebagai media untuk memutar file media pada perangkat anda. Apabila anda mendapatkan blocker pada video player seperti pada gambar berikut:




![](https://s3.amazonaws.com/cdn.freshdesk.com/data/helpdesk/attachments/production/43318855048/original/TlFWszEXDl2jb8j5kan9_RodDQfbgEsqPQ.png?1651201626)![](https://s3.amazonaws.com/cdn.freshdesk.com/data/helpdesk/attachments/production/43318855049/original/C2Wi74ExLEd57WV235wNo1JRlfByv6rSZA.png?1651201626)




Blocker tersebut menandakan terjadi kesalahan saat memproses media, dimana kendala tersebut bisa disebabkan oleh file media yang bermasalah atau media codec yang dimiliki perangkat anda tidak kompatibel untuk memproses media tersebut.




Solusi yang bisa dilakukan:

1. Melakukan pengecekan pada perangkat
2. Mencoba mencari konten lain untuk ditonton
3. Mencoba menonton menggunakan perangkat lain
"""

# %%
alloy_db_engine = engine
def get_context():
    user_id = int(time.time())
    context = {
        "user_id": user_id,
        "visit_id": str(user_id)
    }
    return context
context = get_context()

# %%
context = get_context()
prompt = (
"""You are chatbot for Vidio OTT platform. Your task is to answer to user question
You are a chatbot for the Vidio OTT platform. Today's date is {today}. When responding to user questions, provide information, schedules, or match details only if they are scheduled for a future date relative to {today}. If all provided information pertains to past dates, respond with "I don't have the current information." Avoid giving any outdated information about schedules or matches.

Questions can be related to Vidio products, games, films, or other topics.

For queries specifically about games or arcade games available on Vidio, limit your response to three relevant game options and include direct links for users to play these games.

Here are userful information:
{information} 
""")

information = info

today_date = datetime.now().strftime("%d %B %Y")

prompt_with_history = ChatPromptTemplate.from_messages(
    [
        ("system", prompt),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{user_query}"),
    ]
)

chain = prompt_with_history | model

# print(f"zzzzzzzzzzzzzzzz {prompt_with_history}")
chain_with_history = (RunnableWithMessageHistory(
    chain,
    lambda session_id: AlloyDBChatMessageHistory.create_sync(
        engine=alloy_db_engine,
        session_id=session_id,
        table_name=CHAT_MESSAGE_TABLE_NAME,
    ),
    input_messages_key="user_query",
    history_messages_key="history",
) | StrOutputParser())

config = {"configurable": {"session_id":context["visit_id"]}}
resp_1 = chain_with_history.invoke({"user_query": "bagaimana mendaftar paket mahasiswa", "information": information, "today": today_date}, config=config)
resp_2 = chain_with_history.invoke({"user_query": "apa yang saya tanya tadi", "information": info_2, "today": today_date}, config=config)

Markdown(f"""
xxxxxxxxxxx response 1
{resp_1}


xxxxxxxxxxx response 2
{resp_2}
""")
# Out:
# xxxxxxxxxxx response 1
# Untuk mendaftarkan kampus kamu agar mendapatkan paket Vidio Platinum Mahasiswa, kamu bisa mendaftarkan melalui Form Ini , Pendaftaran terbatas hanya untuk email kampus tertentu. Setelah pendaftaran, kamu bisa coba beli lagi dalam 2x24 jam hari kerja.
#
#
# xxxxxxxxxxx response 2
# ## Vidio Games: Pilihan Seru untuk Hiburan Anda
#
# Vidio Games menawarkan beragam pilihan permainan kasual yang bisa Anda nikmati di aplikasi Vidio. Berikut tiga rekomendasi game yang bisa Anda coba:
#
# **1. Tebak Kata:** Uji kemampuan kosakata Anda dengan menebak kata-kata yang diberikan. Game ini cocok untuk mengasah kemampuan berpikir dan menambah pengetahuan.
#
# **2. Tebak Gambar:** Tantang diri Anda dengan menebak gambar-gambar yang ditampilkan. Permainan ini mengasah kemampuan observasi dan penalaran Anda.
#
# ...

# %%
context = get_context()
prompt = (
"""You are chatbot for Vidio OTT platform. Your task is to answer to user question

Here are userful information:
{information} 
""")

information = info

today_date = datetime.now().strftime("%d %B %Y")

prompt_with_history = ChatPromptTemplate.from_messages(
    [
        ("system", prompt),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{user_query}"),
    ]
)

chain = prompt_with_history | model

# print(f"zzzzzzzzzzzzzzzz {prompt_with_history}")
chain_with_history = (RunnableWithMessageHistory(
    chain,
    lambda session_id: AlloyDBChatMessageHistory.create_sync(
        engine=alloy_db_engine,
        session_id=session_id,
        table_name=CHAT_MESSAGE_TABLE_NAME,
    ),
    input_messages_key="user_query",
    history_messages_key="history",
) | StrOutputParser())

config = {"configurable": {"session_id":context["visit_id"]}}
resp_1 = chain_with_history.invoke({"user_query": "bagaimana mendaftar paket mahasiswa", "information": information, "today": today_date}, config=config)
resp_2 = chain_with_history.invoke({"user_query": "apa yang saya tanya tadi", "information": info_2, "today": today_date}, config=config)

Markdown(f"""
xxxxxxxxxxx response 1
{resp_1}


xxxxxxxxxxx response 2
{resp_2}
""")
# Out:
# xxxxxxxxxxx response 1
# Untuk mendaftar paket mahasiswa, kamu bisa mengikuti langkah-langkah berikut:
#
# 1. **Pastikan email kampus kamu terdaftar.** Kamu bisa mengeceknya di [sini](https://www.vidio.com/pages/243/paket-mahasiswa-whitelisted?layout=false).
# 2. **Daftar melalui formulir ini:** http://vid.id/daftardomain. Pendaftaran terbatas hanya untuk email kampus tertentu.
# 3. **Setelah pendaftaran, tunggu 2x24 jam hari kerja.**
# 4. **Beli paketnya melalui Paywall (https://www.vidio.com/plans?fpc=80) atau halaman Platinum Mahasiswa (https://www.vidio.com/pages/234/paket-mahasiswa?layout=false&utm_source=product&utm_medium=faq_page&utm_campaign=platinum_mahasiswa_2023).**
# 5. **Langsung nonton di Vidio!**
#
# **Catatan:**
#
# * Pastikan kamu sudah **masuk atau daftar dengan email kampus** sebelum membeli paket.
# * Pastikan kamu **belum memiliki paket aktif Platinum di Vidio**.
# * Pastikan kamu **sudah memverifikasi email** kamu.
#
# **Semoga membantu!**
#
#
# ...

# %%
# %load_ext sql
# %sql postgresql://postgres:postgres@localhost:5432/postgres

# %%
# %%sql
# select * from chat_messages order by id desc limit
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(144, '101', {'id': None, 'name': None, 'type': 'ai', 'content': '## Cara Mendaftar Paket Mahasiswa di Vidio Tanpa Email Kampus\n\nJika Anda tidak memiliki email k ... (1168 characters truncated) ... 0.\n\nSemoga informasi ini membantu!', 'example': False, 'tool_calls': [], 'additional_kwargs': {}, 'response_metadata': {}, 'invalid_tool_calls': []}, 'ai'),
#  (143, '101', {'id': None, 'name': None, 'type': 'human', 'content': 'bagaimana kalau tidak punya email', 'example': False, 'additional_kwargs': {}, 'response_metadata': {}}, 'human'),
#  (142, '101', {'id': None, 'name': None, 'type': 'ai', 'content': '## Cara Mendaftar Paket Mahasiswa di Vidio\n\nBerikut langkah-langkah untuk mendaftar paket mahas ... (1260 characters truncated) ... 0.\n\nSemoga informasi ini membantu!', 'example': False, 'tool_calls': [], 'additional_kwargs': {}, 'response_metadata': {}, 'invalid_tool_calls': []}, 'ai'),
# ...

# %%
# %%sql
# select ML_PREDICT_ROW('projects/vidio-quiz-prod/locations/asia-southeast1/publishers/google/models/text-bison', '{"instances":[{"prompt": "What are three advantages of using AlloyDB as my SQL database server?"}], "parameters":{"maxOutputTokens":1024, "topK": 40, "topP":0.8, "temperature":0.2}}');
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# File ~/.pyenv/versions/genai_hackathon_2024/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1818, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1816         conn = self._revalidate_connection()
# -> 1818     context = constructor(
#    1819         dialect, self, conn, execution_options, *args, **kw
#    1820     )
#    1821 except (exc.PendingRollbackError, exc.ResourceClosedError):
#
# File ~/.pyenv/versions/genai_hackathon_2024/lib/python3.10/site-packages/sqlalchemy/engine/default.py:1379, in DefaultExecutionContext._init_compiled(cls, dialect, connection, dbapi_connection, execution_options, compiled, parameters, invoked_statement, extracted_parameters, cache_hit)
#    1378 else:
# ...
